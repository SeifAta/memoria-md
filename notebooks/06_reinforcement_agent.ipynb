# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import json

from utils.llm import generate
from utils.prompt_loader import load_prompt
# Out:
# LLM PROJECT ROOT: C:\Users\seifa\OneDrive\Desktop\amd-hackathon\memoria-md
# ENV EXISTS: True

# %%
from utils.reinforcement_schema import ReinforcementPlan

# %%
with open(
    "../outputs/heart_failure_blueprint.json",
    "r",
    encoding="utf-8"
) as f:

    teaching_blueprint = json.load(f)

# %%
with open(
    "outputs/examiner_report.json",
    "r",
    encoding="utf-8"
) as f:

    examiner_report = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with open(
#       2     "../outputs/examiner_report.json",
#       3     "r",
#       4     encoding="utf-8"
#
# FileNotFoundError: [Errno 2] No such file or directory: '../outputs/examiner_report.json'

# %%
prompt = load_prompt(
    "reinforcement_agent.md",
    TEACHING_BLUEPRINT=json.dumps(
        teaching_blueprint,
        indent=2
    ),
    EXAMINER_REPORT=json.dumps(
        examiner_report,
        indent=2
    )
)

# %%
from utils.llm import generate_structured
reinforcement_plan = generate_structured(
    prompt,
    ReinforcementPlan.model_json_schema()
)

# %%
print(reinforcement_plan)

# %%
from pathlib import Path
import json

output_path = Path("../outputs/reinforcement_plan.json")

with open(
    output_path,
    "w",
    encoding="utf-8"
) as f:

    json.dump(
        reinforcement_plan.model_dump(),
        f,
        indent=2
    )

print("Saved:", output_path)
