# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import json

from utils.llm import generate
from utils.prompt_loader import load_prompt
# Out:
# LLM PROJECT ROOT: C:\Users\seifa\OneDrive\Desktop\amd-hackathon\memoria-md
# ENV EXISTS: True

# %%
from utils.reinforcement_schema import ReinforcementPlan

# %%
with open(
    "../outputs/heart_failure_blueprint.json",
    "r",
    encoding="utf-8"
) as f:

    teaching_blueprint = json.load(f)

# %%
with open(
    "../outputs/examiner_report.json",
    "r",
    encoding="utf-8"
) as f:

    examiner_report = json.load(f)

# %%
from pathlib import Path

outputs = Path("../outputs")

for file in outputs.iterdir():
    print(file.name)
# Out:
# examiner_report.json
# heart_failure_blueprint.json
# heart_failure_case.json
# reinforcement_plan.json

# %%
prompt = load_prompt(
    "reinforcement_agent.md",
    TEACHING_BLUEPRINT=json.dumps(
        teaching_blueprint,
        indent=2
    ),
    EXAMINER_REPORT=json.dumps(
        examiner_report,
        indent=2
    )
)

# %%
from utils.llm import generate_structured
reinforcement_plan = generate_structured(
    prompt,
    ReinforcementPlan.model_json_schema()
)
# Out:
# Trying models/gemini-3.1-flash-lite
# ✓ Success using models/gemini-3.1-flash-lite

# %%
print(reinforcement_plan)
# Out:
# {'session_title': 'Mastering the Heart Failure Clinical Encounter', 'estimated_time_minutes': 15, 'why_this_session': 'Your recent performance highlighted a need to improve the depth of your history taking and the identification of critical precipitating factors in heart failure patients, such as medication non-adherence and the use of contraindicated drugs like NSAIDs.', 'focus_area': 'Comprehensive History Taking and Identification of Precipitating Factors in Heart Failure', 'review_points': ['Heart failure is a clinical syndrome defined by symptoms, signs, and cardiac abnormality.', 'Common symptoms include dyspnea (orthopnea, PND), cough, fatigue, and peripheral edema.', 'Precipitating factors for acute decompensation include non-adherence to salt/fluid/medications, infections, arrhythmias, and drugs like NSAIDs.', 'Drugs to avoid in heart failure include NSAIDs, COX-2 inhibitors, corticosteroids, and non-dihydropyridine CCBs.', 'The NYHA functional classification (I-IV) is essential for assessing symptom severity and impact on daily activities.', 'A thorough history must include past medical history (IHD, HTN, Diabetes) and social history (smoking, diet) to identify etiologies.'], 'rapid_fire_questions': ['Why is it clinically important to specifically ask a heart failure patient about recent NSAID use?', "How does the NYHA classification help you determine the severity of a patient's functional limitation?", 'What is the difference between orthopnea and paroxysmal nocturnal dyspnea in terms of patient presentation?', 'Why might a patient with heart failure present with a dry or frothy cough?', 'Which specific components of a social history are most relevant to managing a patient with chronic heart failure?', 'If a patient reports symptoms at rest, which NYHA class are they in, and what does this imply about their stability?', 'Why is medication adherence a critical inquiry during a heart failure review?'], 'mini_case_goal': "To perform a structured, comprehensive history that identifies the patient's current functional status and uncovers potential precipitating factors for their decompensation.", 'success_criteria': ['Systematically inquire about all key heart failure symptoms: dyspnea, orthopnea, PND, cough, and edema.', 'Explicitly ask about medication adherence and the use of over-the-counter medications, specifically NSAIDs.', "Assess the functional impact of symptoms on the patient's daily activities.", 'Review relevant past medical history including hypertension, diabetes, and previous cardiac events.', 'Identify potential precipitating factors for the current presentation during the history taking.'], 'recommended_next_case': 'Chronic Heart Failure Management and Decompensation Assessment'}
