# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# c:\Users\seifa\OneDrive\Desktop\amd-hackathon\memoria-md

# %%
from utils.llm import generate
from utils.pdf import extract_pdf_text
from utils.prompt_loader import load_prompt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from utils.llm.py import generate
#       2 from utils.pdf import extract_pdf_text
#       3 from utils.prompt_loader import load_prompt
#
# ModuleNotFoundError: No module named 'utils.llm.py'; 'utils.llm' is not a package
